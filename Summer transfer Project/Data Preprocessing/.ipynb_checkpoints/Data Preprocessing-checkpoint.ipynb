# %%
import io, requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.relative_locator import locate_with
import time
import seaborn as sns

# %% [markdown]
#  <h2 style="color:blue;">Read data and display it</h2>

# %%
data = pd.read_csv('Summer22_FootballTransfers.csv')

# %%
data.head()
# Out:
#             name          position   age        origin_club  \
# 0   Amine Gouiri    Centre-Forward  22.0           OGC Nice
# 1     Umar Sadiq    Centre-Forward  25.0         UD Almería
# 2   Carlos Soler  Central Midfield  25.0        Valencia CF
# 3  Manuel Akanji       Centre-Back  27.0  Borussia Dortmund
# 4      Wout Faes       Centre-Back  24.0        Stade Reims
#
#   league_origin_club country_origin_club             new_club league_new_club  \
# 0            Ligue 1              France     Stade Rennais FC         Ligue 1
# 1             LaLiga               Spain        Real Sociedad          LaLiga
# 2             LaLiga               Spain  Paris Saint-Germain         Ligue 1
# 3         Bundesliga             Germany      Manchester City  Premier League
# 4            Ligue 1              France       Leicester City  Premier League
#
#   country_new_club     cost date_of_transfer
# 0           France  €42.00m         9/1/2022
# 1            Spain  €18.00m         9/1/2022
# 2           France  €50.00m         9/1/2022
# 3          England  €30.00m         9/1/2022
# 4          England  €10.00m         9/1/2022

# %% [markdown]
# <h2 style="color:blue;">Data insigths</h2>

# %%
print("Data has  " + str(data.shape[0]) + "  records and  " + str(data.shape[1]) + "  features")
# Out:
# Data has  33625  records and  11  features

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33625 entries, 0 to 33624
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 33620 non-null  object
#  1   position             33615 non-null  object
#  2   age                  33477 non-null  float64
#  3   origin_club          33620 non-null  object
#  4   league_origin_club   32685 non-null  object
#  5   country_origin_club  32690 non-null  object
#  6   new_club             33615 non-null  object
#  7   league_new_club      28047 non-null  object
#  8   country_new_club     28051 non-null  object
#  9   cost                 33621 non-null  object
#  10  date_of_transfer     33625 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 2.8+ MB

# %%
data.isna().sum()         # na values
# Out:
# name                      5
# position                 10
# age                     148
# origin_club               5
# league_origin_club      940
# country_origin_club     935
# new_club                 10
# league_new_club        5578
# country_new_club       5574
# cost                      4
# date_of_transfer          0
# dtype: int64

# %%
len(data['position'].value_counts())
# Out:
# 16

# %%
data['position'].value_counts()
# Out:
# Centre-Back           5338
# Centre-Forward        4997
# Central Midfield      3627
# Goalkeeper            3359
# Defensive Midfield    2488
# Right-Back            2414
# Left-Back             2360
# Attacking Midfield    2303
# Left Winger           2260
# Right Winger          2170
# midfield               532
# Right Midfield         463
# Left Midfield          414
# attack                 316
# Second Striker         314
# defence                260
# Name: position, dtype: int64

# %%
print(len(data.new_club.value_counts()))
print(len(data.origin_club.value_counts()))
# Out:
# 6317
# 5819

# %%
#data['position'].replace(['Centre-Back', 'Right-Back', 'Left-Back'], 'defence', inplace=True)
#data['position'].replace(['Central Midfield', 'Defensive Midfield', 'Attacking Midfield','Right Midfield', 'Left Midfield'], 'midfield', inplace=True)
#data['position'].replace(['Centre-Forward', 'Left Winger', 'Right Winger','Second Striker'], 'attack', inplace=True)

# %% [markdown]
# <h2 style="color:blue;">Data cleaning</h2>
# <div>
#
#     1 data in wrong format --> 'cost' column data type
#     2 data missing at ['age', 'postiton', 'origin_club', 'new_club']
#     3 wrong Data
# </div>
#
# ## 1 Customize datatype of   ' cost '   column as integer value

# %%
data.cost.dtype
# Out:
# dtype('O')

# %%
def customizer(val):
    str(val)          # we used str() because float-point number not accessable ---> 'float value is not subscriptable object'
    if (val[-1] == 'm'): 
        val = pd.to_numeric(val[1:-1])  
        return val*10**6
    
    elif (val[-1] == '.'):
        val = pd.to_numeric(val[1:-3])
        return val*10**3
    
    else:
        return ''

# %%
customizer("€1th.")
# Out:
# 1000

# %%
data.cost = data.cost.apply(lambda val : pd.to_numeric(str(val)[1:-1])*10**6 if(str(val)[-1] == 'm') else pd.to_numeric(str(val)[1:-3])*10**3)

# %%
data.head()
# Out:
#             name          position   age        origin_club  \
# 0   Amine Gouiri    Centre-Forward  22.0           OGC Nice
# 1     Umar Sadiq    Centre-Forward  25.0         UD Almería
# 2   Carlos Soler  Central Midfield  25.0        Valencia CF
# 3  Manuel Akanji       Centre-Back  27.0  Borussia Dortmund
# 4      Wout Faes       Centre-Back  24.0        Stade Reims
#
#   league_origin_club country_origin_club             new_club league_new_club  \
# 0            Ligue 1              France     Stade Rennais FC         Ligue 1
# 1             LaLiga               Spain        Real Sociedad          LaLiga
# 2             LaLiga               Spain  Paris Saint-Germain         Ligue 1
# 3         Bundesliga             Germany      Manchester City  Premier League
# 4            Ligue 1              France       Leicester City  Premier League
#
#   country_new_club        cost date_of_transfer
# 0           France  42000000.0         9/1/2022
# 1            Spain  18000000.0         9/1/2022
# 2           France  50000000.0         9/1/2022
# 3          England  30000000.0         9/1/2022
# 4          England  10000000.0         9/1/2022

# %%
data.dtypes
# Out:
# name                    object
# position                object
# age                    float64
# origin_club             object
# league_origin_club      object
# country_origin_club     object
# new_club                object
# league_new_club         object
# country_new_club        object
# cost                   float64
# date_of_transfer        object
# dtype: object

# %%
data.age.describe()
# Out:
# count    33477.000000
# mean        25.020432
# std          4.784488
# min         15.000000
# 25%         21.000000
# 50%         24.000000
# 75%         28.000000
# max         46.000000
# Name: age, dtype: float64

# %%
data.age = data.age.astype('f2')

# %%
data.cost.describe()
# Out:
# count    3.362100e+04
# mean     4.783108e+05
# std      2.429271e+06
# min      8.000000e+03
# 25%      5.000000e+04
# 50%      1.000000e+05
# 75%      2.500000e+05
# max      1.500000e+08
# Name: cost, dtype: float64

# %%
data.cost = data.cost.astype('f4')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33625 entries, 0 to 33624
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 33620 non-null  object
#  1   position             33615 non-null  object
#  2   age                  33477 non-null  float16
#  3   origin_club          33620 non-null  object
#  4   league_origin_club   32685 non-null  object
#  5   country_origin_club  32690 non-null  object
#  6   new_club             33615 non-null  object
#  7   league_new_club      28047 non-null  object
#  8   country_new_club     28051 non-null  object
#  9   cost                 33621 non-null  float32
#  10  date_of_transfer     33625 non-null  object
# dtypes: float16(1), float32(1), object(9)
# memory usage: 2.5+ MB

# %% [markdown]
# ### 2 Wrong Data

# %%
data[data['country_origin_club']=='Egypt']
# Out:
#                    name          position   age        origin_club  \
# 36        Mohamed Sobhi        Goalkeeper  23.0         Zamalek SC
# 41      Mohanad Lasheen  Central Midfield  26.0   Tala'ea El Gaish
# 42         Mohamed Reda  Central Midfield  21.0      Wadi Degla FC
# 43           Ahmed Atef    Centre-Forward  24.0      Wadi Degla FC
# 56         Yassin Marei       Centre-Back  20.0     Zamalek SC U21
# ...                 ...               ...   ...                ...
# 32786  Mostafa El Rouby        Goalkeeper  21.0  Wadi Degla FC U23
# 32807        Moaz Ahmed       Centre-Back  19.0  Wadi Degla FC U23
# 33287     Marwan Shawky    Centre-Forward  22.0      Wadi Degla FC
# 33351        Alaa Abbas       Left Winger  31.0   Harras El Hodoud
# 33441       Ahmed Farag    Centre-Forward  21.0  Wadi Degla FC U23
#
#       league_origin_club country_origin_club      new_club league_new_club  \
# 36        Premier League               Egypt     Pharco FC  Premier League
# 41        Premier League               Egypt     Future FC  Premier League
# 42                 Egypt               Egypt     Future FC  Premier League
# 43                 Egypt               Egypt     Future FC  Premier League
# 56                 Egypt               Egypt     Pharco FC  Premier League
# ...                  ...                 ...           ...             ...
# 32786              Egypt               Egypt  Without Club             NaN
# 32807              Egypt               Egypt  Without Club             NaN
# 33287              Egypt               Egypt  Without Club             NaN
# 33351     Premier League               Egypt  Without Club             NaN
# 33441              Egypt               Egypt  Without Club             NaN
#
#       country_new_club      cost date_of_transfer
# 36               Egypt  500000.0         9/1/2022
# 41               Egypt  500000.0         9/1/2022
# 42               Egypt  150000.0         9/1/2022
# 43               Egypt  200000.0         9/1/2022
# 56               Egypt   50000.0         9/1/2022
# ...                ...       ...              ...
# 32786              NaN   25000.0         7/1/2022
# 32807              NaN   25000.0         7/1/2022
# 33287              NaN   25000.0         7/1/2022
# 33351              NaN   50000.0         7/1/2022
# 33441              NaN   50000.0         7/1/2022
#
# [118 rows x 11 columns]

# %%
#drop unuseful features
data.drop(['name', 'league_origin_club', 'league_new_club','date_of_transfer'], axis=1, inplace= True)

# %%
print(f"No. origin country : {len(data['country_origin_club'].value_counts())}")
print(f"No. new country : {len(data['country_new_club'].value_counts())}")
# Out:
# No. origin country : 153
# No. new country : 139

# %% [markdown]
# ### 3 Missing Data
# at 'positian' Column

# %%
c = 0
for i in data.position.isna():
    if i == True: 
        print(c)
    c+=1
# Out:
# 2753
# 2754
# 2755
# 2756
# 2757
# 25188
# 25189
# 25190
# 25191
# 25192

# %%
data[2753:2758]
# Out:
#      name position   age           origin_club country_origin_club  \
# 2753  NaN      NaN  25.0          Without Club                 NaN
# 2754  NaN      NaN  30.0       Difaâ El Jadida             Morocco
# 2755  NaN      NaN  22.0  HNK Cibalia Vinkovci             Croatia
# 2756  NaN      NaN  25.0             Torino FC               Italy
# 2757  NaN      NaN  22.0              FC Porto            Portugal
#
#                        new_club country_new_club       cost
# 2753  University of Pretoria FC     South Africa    25000.0
# 2754        Olympique Khouribga          Morocco   325000.0
# 2755                   NK Lucko          Croatia   100000.0
# 2756                 Palermo FC            Italy  1600000.0
# 2757                Casa Pia AC         Portugal  3000000.0

# %%
data.fillna({'position': {2753: 'Right-Back' , 2754: 'Centre-Forward', 2755: 'Centre-Back', 2756: 'midfield', 2757: 'midfield'}},inplace=True)

# %%
data[25188:25193]
# Out:
#                    name position  age origin_club country_origin_club  \
# 25188          Eljo Iba      NaN  NaN         NaN           Indonesia
# 25189      Ángel Robles      NaN  NaN         NaN              Mexico
# 25190    Gian-Luca Reck      NaN  NaN         NaN             Germany
# 25191      Kian Harratt      NaN  NaN         NaN             England
# 25192  Michael Pavlovic      NaN  NaN         NaN            Slovenia
#
#                     new_club country_new_club      cost
# 25188     Persipura Jayapura        Indonesia  100000.0
# 25189  Club Atlético Morelia           Mexico  200000.0
# 25190           1.FC Bocholt          Germany   10000.0
# 25191          Bradford City          England   50000.0
# 25192               FC Koper         Slovenia  300000.0

# %%
playersNames = data.name[25188:25193].tolist()
playersNames
# Out:
# ['Eljo Iba',
#  'Ángel Robles',
#  'Gian-Luca Reck',
#  'Kian Harratt',
#  'Michael Pavlovic']

# %%
ffx = webdriver.Chrome()

ffx.get("https://www.transfermarkt.com")
print('position age')
li7 = []
for i in playersNames:
    ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').send_keys(i) # Search with player name
    ffx.find_element(By.CSS_SELECTOR,'[class="tm-header__input--search-send"]').send_keys(Keys.ENTER) # press Enter Key
    
    
    for player in ffx.find_elements(By.CSS_SELECTOR,'td[class= "zentriert"]'):
        li7.append(player.text)
    ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').clear()
    print(f'{li7[0]}   {li7[2]}')
ffx.quit()
print(li7)

# %%
data.fillna({'position': {25188: 'Right-Back' , 25189: 'Centre-Forward', 25190: 'GoalKeeper', 25191: 'attack', 25192: 'Left-Back'} 
              , 'age': {25188: 29 , 25189: 21, 25190: 20, 25191: 20, 25192: 21}
              , 'origin_club': {25188: 'Persiba' , 25189: 'Puebla', 25190: 'Lippstadt', 25191: 'Huddersfield Town', 25192: 'Olimpija'}}
             ,inplace=True)

# %%
for i in data['position'].value_counts().index:
    print(i)
# Out:
# Centre-Back
# Centre-Forward
# Central Midfield
# Goalkeeper
# Defensive Midfield
# Right-Back
# Left-Back
# Attacking Midfield
# Left Winger
# Right Winger
# midfield
# Right Midfield
# Left Midfield
# attack
# Second Striker
# defence
# GoalKeeper

# %% [markdown]
# ### data missing in 'new_club' column

# %%
data.isna().sum()         # na values
# Out:
# name                      5
# position                  0
# age                     143
# origin_club               0
# country_origin_club     935
# new_club                 10
# country_new_club       5574
# cost                      4
# dtype: int64

# %%
c = 0
for i in data.new_club.isna():
    if i == True: 
        print(c)
    c+=1
# Out:
# 5420
# 5421
# 5422
# 5423
# 9278
# 9279
# 31461
# 31462
# 31463
# 31464

# %%
data[5420:5424]
# Out:
#                    name            position   age        origin_club  \
# 5420       Matteo Gullo              attack  22.0  Rende Calcio 1968
# 5421     Hamed Alizadeh  Attacking Midfield  22.0        Rayka Babol
# 5422  Thanachach Phocha         Centre-Back  21.0    Muangkan United
# 5423      Richard Keogh         Centre-Back  35.0       Blackpool FC
#
#      country_origin_club new_club country_new_club      cost
# 5420               Italy      NaN            Italy   10000.0
# 5421                Iran      NaN             Iran   50000.0
# 5422            Thailand      NaN         Thailand   50000.0
# 5423             England      NaN          England  250000.0

# %%
names = data.name[5420:5424].tolist()
print(names)
# Out:
# ['Matteo Gullo', 'Hamed Alizadeh', 'Thanachach Phocha', 'Richard Keogh']

# %%
ffx = webdriver.Chrome()

ffx.get("https://www.transfermarkt.com")
li8 = []
for i in names:
    ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').send_keys(i) # Search with player name
    ffx.find_element(By.CSS_SELECTOR,'[class="tm-header__input--search-send"]').send_keys(Keys.ENTER) # press Enter Key
    player = ffx.find_element(By.CSS_SELECTOR,'td[class= "hauptlink"]')
    url = player.find_element(By.TAG_NAME,'a').get_attribute('href')
    ffx.get(url)
    li8.append(ffx.find_element(By.CSS_SELECTOR,'[class="data-header__club"]').find_element(By.TAG_NAME,'a').text)
    ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').clear()
ffx.quit()
print(li8)

# %%
li8 = ['Vigor Lamezia', 'Darya Caspian', 'Banbueng FC', 'Ipswich']

# %%
data.fillna({'new_club': {5420: 'Vigor Lamezia' , 5421: 'Darya Caspian', 5422: 'Banbueng FC', 5423: 'Ipswich'}},inplace=True)

# %%
data[9278:9280]
# Out:
#                name          position   age origin_club country_origin_club  \
# 9278  Uros Poljanec        Goalkeeper  30.0  NK Vinodol             Croatia
# 9279   Bastien Héry  Central Midfield  30.0  Finn Harps             Ireland
#
#            new_club country_new_club     cost continent
# 9278  Vigor Lamezia         Slovenia  10000.0       NaN
# 9279  Darya Caspian          Ireland  50000.0       NaN

# %%
names = data.name[9278:9280].tolist()
print(names)
# Out:
# ['Uros Poljanec', 'Bastien Héry']

# %%
ffx = webdriver.Chrome()

ffx.get("https://www.transfermarkt.com")
li1 = []
for i in names:
    ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').send_keys(i) # Search with player name
    ffx.find_element(By.CSS_SELECTOR,'[class="tm-header__input--search-send"]').send_keys(Keys.ENTER) # press Enter Key
    player = ffx.find_element(By.CSS_SELECTOR,'td[class= "hauptlink"]')
    url = player.find_element(By.TAG_NAME,'a').get_attribute('href')
    ffx.get(url)
    li1.append(ffx.find_element(By.CSS_SELECTOR,'[class="data-header__club"]').find_element(By.TAG_NAME,'a').text)
    ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').clear()
ffx.quit()
print(li1)
# Out:
# ['NK Pesnica', 'Galway United']

# %%
dic = dict(zip([9278,9279], li1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10388/39571648.py in <module>
# ----> 1 dic = dict(zip([9278,9279], li1))
#
# NameError: name 'li1' is not defined

# %%
data.fillna({'new_club': dic},inplace=True)

# %%
data[31461:31465]
# Out:
#                     name            position   age          origin_club  \
# 31461  Farid Mohammadian  Defensive Midfield   NaN  Esteghlal Mollasani
# 31462      Sajjad Abbasi  Attacking Midfield  30.0   Mes Shahr Babak FC
# 31463  Abdallahi Mahmoud    Central Midfield  22.0   Deportivo Alavés B
# 31464        Gleb Shilov          Right-Back  22.0    Khimik Dzerzhinsk
#
#       country_origin_club new_club country_new_club      cost
# 31461                 NaN      NaN              NaN   50000.0
# 31462                 NaN      NaN              NaN  100000.0
# 31463                 NaN      NaN            Spain  600000.0
# 31464                 NaN      NaN              NaN   75000.0

# %%
names = data.name[31461:31465].tolist()
print(names)
# Out:
# ['Farid Mohammadian', 'Sajjad Abbasi', 'Abdallahi Mahmoud', 'Gleb Shilov']

# %%
ffx = webdriver.Chrome()

ffx.get("https://www.transfermarkt.com")
li2 = []
for i in names:
    ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').send_keys(i) # Search with player name
    ffx.find_element(By.CSS_SELECTOR,'[class="tm-header__input--search-send"]').send_keys(Keys.ENTER) # press Enter Key
    player = ffx.find_element(By.CSS_SELECTOR,'td[class= "hauptlink"]')
    url = player.find_element(By.TAG_NAME,'a').get_attribute('href')
    ffx.get(url)
    li2.append(ffx.find_element(By.CSS_SELECTOR,'[class="data-header__club"]').find_element(By.TAG_NAME,'a').text)
    ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').clear()
ffx.quit()
print(li2)
# Out:
# ['Without Club', 'Without Club', 'Alavés', 'Without Club']

# %%
dic = dict(zip([x for x in range(31461,31465,1)], li2))
# Out:
# {31461: 'Without Club',
#  31462: 'Without Club',
#  31463: 'Alavés',
#  31464: 'Without Club'}

# %%
data.fillna({'new_club': dic},inplace=True)

# %%
c = 0
for i in data.cost.isna():
    if i == True: 
        print(c)
    c+=1
# Out:
# 21008
# 21009
# 21010
# 21011

# %%
data[21008:21012]
# Out:
#                   name          position   age          origin_club  \
# 21008  Federico Scappi       Centre-Back  28.0         AS Fidentina
# 21009   Mihkel Ainsalu  Central Midfield  26.0          FCI Levadia
# 21010    Andrea Grassi  Central Midfield  28.0  ASD Gabicce Gradara
# 21011    Michele Turci        Right-Back  27.0      ASD Savignanese
#
#       country_origin_club            new_club country_new_club  cost
# 21008               Italy         AC Fabbrico              NaN   NaN
# 21009             Estonia          SC Telstar              NaN   NaN
# 21010               Italy     La Fiorita 1967              NaN   NaN
# 21011               Italy  Sasso Marconi 1924              NaN   NaN

# %%
namesOfcost = data.name[21008:21012].tolist()

# %%
ffx = webdriver.Chrome()

ffx.get("https://www.transfermarkt.com")
li3 = []
for i in namesOfcost:
    ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').send_keys(i) # Search with player name
    ffx.find_element(By.CSS_SELECTOR,'[class="tm-header__input--search-send"]').send_keys(Keys.ENTER) # press Enter Key
    
    player = ffx.find_element(By.CSS_SELECTOR,'td[class= "rechts hauptlink"]')
    li3.append(player.text)
    
    ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').clear()
ffx.quit()
print(li3)
# Out:
# ['€75Th.', '€100Th.', '€10Th.', '€75Th.']

# %%
customizer('€75Th.')
# Out:
# 75000

# %%
dic = dict(zip([x for x in range(21008,21012,1)], [ customizer(y) for y in li3]))
dic
# Out:
# {21008: 75000, 21009: 100000, 21010: 10000, 21011: 75000}

# %%
data.fillna({'cost': dic},inplace=True)

# %% [markdown]
# <h2 style="color:blue;">Data cleaning</h2>
# <div>
#
#     1 data in wrong format --> 'cost' column data type                                ------------->   Done
#     2 wrong Data                                                                      ------------->   Done
#     3 data missing at ['age', 'postiton', 'origin_club', 'new_club']                  ------------->   Done Expect age col
#
# </div>

# %% [markdown]
# ### Fillna Age column

# %%
print('Average in ')
for i in data['country_origin_club'].value_counts().index[0:].to_list():
    print( f'{i} :        { int(data.age[data.country_origin_club == i].mean()) }' )
# Out:
# Average in
# Italy :        24
# Spain :        25
# Germany :        23
# Russia :        23
# Turkey :        25
# England :        25
# France :        24
# Romania :        23
# Greece :        25
# Serbia :        24
# Iran :        26
# Portugal :        25
# Bosnia-Herzegovina :        23
# Netherlands :        23
# Croatia :        22
# Switzerland :        24
# Hungary :        25
# Slovakia :        22
# Czech Republic :        24
# Bulgaria :        24
# Poland :        24
# Brazil :        25
# Belgium :        25
# Israel :        25
# Ukraine :        25
# Thailand :        27
# Slovenia :        23
# Austria :        23
# Indonesia :        26
# Wales :        25
# Mexico :        24
# Denmark :        23
# Scotland :        24
# Cyprus :        26
# China :        25
# Algeria :        26
# South Africa :        27
# India :        25
# Colombia :        25
# Malta :        27
# North Macedonia :        25
# United States :        22
# Argentina :        26
# Northern Ireland :        24
# Morocco :        27
# Sweden :        23
# Armenia :        25
# Montenegro :        24
# Albania :        25
# Kosovo :        25
# Georgia :        25
# Saudi Arabia :        28
# Tunisia :        26
# Andorra :        27
# Luxembourg :        25
# El Salvador :        27
# Belarus :        23
# Guatemala :        28
# Paraguay :        26
# Norway :        24
# Uruguay :        26
# Kazakhstan :        25
# Peru :        26
# Egypt :        28
# San Marino :        27
# Gibraltar :        26
# Australia :        26
# Japan :        24
# Hongkong :        25
# Uzbekistan :        26
# Costa Rica :        27
# Panama :        24
# Bolivia :        26
# Korea, South :        25
# Moldova :        23
# Ghana :        24
# Azerbaijan :        26
# Syria :        27
# Iraq :        26
# Honduras :        27
# Qatar :        28
# Finland :        23
# United Arab Emirates :        26
# Tajikistan :        24
# Ecuador :        25
# Chile :        27
# Latvia :        23
# Iceland :        24
# Ireland :        22
# New Zealand :        24
# Lithuania :        23
# Vietnam :        26
# Bangladesh :        24
# Fiji :        27
# Kyrgyzstan :        25
# Estonia :        21
# Oman :        28
# Canada :        23
# Lebanon :        31
# Kuwait :        27
# Monaco :        23
# Libya :        27
# Venezuela :        22
# Bahrain :        28
# Liechtenstein :        22
# Palästina :        26
# Faroe Islands :        24
# Ethiopia :        23
# Cote d'Ivoire :        24
# Mongolia :        26
# Malaysia :        30
# Jordan :        28
# Myanmar :        26
# Guinea :        24
# Maldives :        31
# Nigeria :        25
# Timor-Leste :        19
# Nepal :        26
# Tanzania :        30
# Nicaragua :        27
# Philippines :        25
# Chinese Taipei :        26
# Sudan :        25
# Equatorial Guinea :        29
# The Gambia :        21
# Singapore :        27
# Angola :        29
# Dominican Republic :        24
# Cambodia :        26
# Cameroon :        24
# Sierra Leone :        22
# Mozambique :        25
# Zambia :        24
# Mali :        24
# Burkina Faso :        24
# Mauritania :        27
# Djibouti :        32
# Gabon :        29
# Neukaledonien :        21
# Eswatini :        30
# Vanuatu :        22
# Cuba :        29
# Solomon Islands :        31
# Congo :        19
# Guadeloupe :        26
# Uganda :        28
# Laos :        30
# Trinidad and Tobago :        25
# Niger :        25
# Rwanda :        23
# Senegal :        23
# Madagascar :        29
# Chinese Taipei (Taiwan) :        26

# %%
c = 0
namesOfAge = []
indexOfAge = []
for i in data.age.isna():
    if i == True: 
        namesOfAge.append(data.name.iloc[c])
        indexOfAge.append(c)
    c+=1

# %%
print(len(namesOfAge))
namesOfAge
# Out:
# 148
# ['Mohammadmehdi Mohammadpour',
#  'Harry Irving',
#  'Ebrahim Moradi',
#  'Hadi Kianpour',
#  'Tawfik Idsghir',
#  'Azad Jafarzadeh',
#  'Hamed Ketab Ghaleh',
#  'Mohammadreza Eghbali',
#  'Vahid Amani',
#  'Mohammed Ajeel',
#  'Ali Hadadifar',
#  'Salim Barhoom',
#  'Asghar Khosravi',
#  'Mohammad Savari',
#  'Saeid Mehrali',
#  'Moses Odo',
#  'Amir Mohammad Monsef',
#  'Matin Parsa',
#  'Igor Kukulicic',
#  'Anil Julevic',
#  'Arya Kamali',
#  'Enock Lusiama',
#  'Nader Mohammadnejad',
#  'Amir Alidadi',
#  'Ghadir Aghajani',
#  'Seth Karunaratne',
#  'Touraj Aghayari',
#  'Keyvan Salehi',
#  'Mick Reid',
#  'Jordan Neal',
#  'Mojtaba Khosravi',
#  'Joe Davis',
#  'Jovan Radisic',
#  'Malik Sylvester',
#  'Amer Dandashi',
#  'Jonibek Kochimov',
#  'Abdumutal Tursunkulov',
#  'Alireza Ebrahimi',
#  'Majd Khushman',
#  'Gabriel Thór Thórdarson',
#  'Mohammad Norouzi',
#  'Sajjad Terjerou',
#  'Ibrahim Al-Taweel',
#  'Mehdi Berihi',
#  'Abbas Kandoul',
#  'Farid Hamrang',
#  'Mohammadreza Raoufi Manesh',
#  'Rabie Sorur',
#  'Reza Rezaei',
#  'Luke White',
#  'Jack Mitchell',
#  'Sohrab Polgardani',
#  'Mohsen Seifi',
#  'Amir Mohammad Monsef',
#  'Sajjad Tamimi',
#  'Mohammad Saberizadeh',
#  'Masoud Ramezani',
#  'Alireza Zare',
#  'Meysam Zamani',
#  'Abdolsamad Ahmadi',
#  'Sadegh Alousabih',
#  'Efekan Çolak',
#  'Mohammad Amin Saeidavi',
#  'Ebrahim Rezazadeh',
#  'Mohammad Qalfat',
#  'Paulo Gali',
#  'Peyman Poursadeghi',
#  'Milad Ahmadi',
#  'Eljo Iba',
#  'Ángel Robles',
#  'Gian-Luca Reck',
#  'Kian Harratt',
#  'Michael Pavlovic',
#  'Alex Mort',
#  'Jack Eccles',
#  'Fergus Gillion',
#  'Mikkel Rod',
#  'Anderson Gómez',
#  'Luke Pritchard',
#  'William Vincent',
#  'Meysam Namvar',
#  'Fernando Ruíz',
#  'Roberto Niebles',
#  'Laurent Xhylani',
#  'Jurgen Serna',
#  'Rinor Brahimi',
#  'Harry Irving',
#  'Khetukuthula Ndlovu',
#  'Mohammad Jaber',
#  'Wálter Maldonado',
#  'Jorge Escobar',
#  'Juan Carbonell',
#  'Yonatan Sandoval',
#  'Mircea Mihai',
#  'Dei Gatkek',
#  'Andile Fakude',
#  'Slobodan Ivovic',
#  'Hakim Hazbaveipour',
#  'Mostafa Zeynali',
#  'Vahid Shaker',
#  'Masoud Asadi',
#  'Nima Eskandarizadeh',
#  'Mohammad Hossein Chegini',
#  'Farid Mohammadian',
#  'Hossein Afarin Zad',
#  'Reza Antik',
#  'Pouya Azizpour',
#  'Behnam Mohammad Zamani',
#  'Ghassen Bardia',
#  'Aria Sadeghi',
#  'Keyvan Mohammadnejad',
#  'Nkululeko Hlongo',
#  'Fayaz Mirdoraghi',
#  'Amir Ghalamara',
#  'Ali Badavi',
#  'Bornwise Ndzalama',
#  'Tshepo Mathiba',
#  'Mohanad Heydari',
#  'Abbas Aboudi',
#  'Mohammad Niazpour',
#  'Sepehr Shabani',
#  'S. Hoyos',
#  'Milad Daryanavardi',
#  'Amir Abbas Hassani',
#  'Amir Mohammadnejad',
#  'Hassan Ghasemi',
#  'Amin Basati',
#  'Leandro Rodriguez',
#  'Jonathan Orellana',
#  'Pedro Chic',
#  'Jalal Al-Dakar',
#  'Marlon Rancho',
#  'Cameron Dutton',
#  'Hesam Gholamian',
#  'Eric Durnell',
#  'Jeffry Aguilar',
#  'Alireza Shirzad',
#  'Peter Evans',
#  'Fandi Achmad',
#  'Adrián Flores',
#  'Reynaldiño Verley',
#  'Hossein Sharifi',
#  'Reza Jalali',
#  'Mahamadou Dramé',
#  'Lucas Davies',
#  'Boris Bissemou',
#  'Hossein Norouzi',
#  'Erfan Sharifi']

# %%
ffx = webdriver.Chrome()
ffx.get("https://www.transfermarkt.com")
print('index :    age ')
li4 = []
Idx = []
try:
    for i in namesOfAge:
        ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').send_keys(i) # Search with player name
        ffx.find_element(By.CSS_SELECTOR,'[class="tm-header__input--search-send"]').send_keys(Keys.ENTER) # press Enter Key
        for player in ffx.find_elements(By.CSS_SELECTOR,'td[class= "zentriert"]'):
            x = player.text
            li4.append(x)
        if li4[2] != '-' :
            c = data[data.name == i ].index[0]
            print(f'{c}   :  {li4[2]}')
            Idx.append(c)
        ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').clear()
        c+=1
except :
    c+=1
ffx.quit()
# Out:
# index :    age
# 4495   :  37
# 6973   :  22
# 8253   :  22
# 10008   :  32
# 12395   :  38
# 12564   :  27
# 13974   :  29
# 23171   :  29
# 25742   :  20
# 25945   :  54
# 26003   :  23
# 26074   :  54
# 27572   :  23
# 32895   :  40
# 33174   :  29
# 33243   :  28
# 33423   :  27
# 29557   :  30

# %%
ages = [37, 22, 22, 32, 38, 27, 29, 29, 20, 54, 23, 54, 23, 40, 29, 28, 27, 30]
Idx = [4495,6973, 8253, 10008, 12395, 12564, 13974, 23171, 25742, 25945, 26003, 26074, 27572, 32895, 33174, 33243,33423,29557]

# %%
dic = dict(zip(Idx, ages))

# %%
dic
# Out:
# {4495: 37,
#  6973: 22,
#  8253: 22,
#  10008: 32,
#  12395: 38,
#  12564: 27,
#  13974: 29,
#  23171: 29,
#  25742: 20,
#  25945: 54,
#  26003: 23,
#  26074: 54,
#  27572: 23,
#  32895: 40,
#  33174: 29,
#  33243: 28,
#  33423: 27,
#  29557: 30}

# %%
data.fillna({'age': dic},inplace=True)

# %% [markdown]
# ### Replace na values in age column

# %%
data.age.isna().sum()         # na values
# Out:
# 126

# %%
url = 'https://raw.githubusercontent.com/reganjohn/BHI/master/topology/country-capitals.csv'
req = requests.get(url).content
countryData = pd.read_csv(io.StringIO(req.decode('latin1')))
countryData.head()
# Out:
#                                     country            capital   latitude  \
# 0                                Somaliland           Hargeisa   9.550000
# 1  South Georgia and South Sandwich Islands  King Edward Point -54.283333
# 2       French Southern and Antarctic Lands  Port-aux-Franais -49.350000
# 3                                 Palestine          Jerusalem  31.766667
# 4                             Aland Islands          Mariehamn  60.116667
#
#    longitude countryCode   continent
# 0  44.050000         NaN      Africa
# 1 -36.500000          GS  Antarctica
# 2  70.216667          TF  Antarctica
# 3  35.233333          PS        Asia
# 4  19.900000          AX      Europe

# %%
countryData.drop(['capital', 'latitude', 'longitude', 'countryCode'], axis=1, inplace=True)

# %%
g = countryData.groupby('continent')

# %%
#create a new column
data['continent'] = data.country_origin_club

# %%
for i in g.country:
    print(i[0])
# Out:
# Africa
# Antarctica
# Asia
# Australia
# Central America
# Europe
# North America
# South America

# %%
li = g.get_group("Africa").country.tolist()
for i in ["DR Congo","Cote d'Ivoire",'Botsuana', 'Réunion', 'Congo', 'Eswatini']:
    li.append(i)
data.continent.replace(li,'africa',inplace=True)

# %%
data.continent.replace(g.get_group("Antarctica").country.tolist(),'Antarctica',inplace=True)

# %%
li = g.get_group("Asia").country.tolist()
for i in ["Palästina",'Hongkong','Korea, South', 'Chinese Taipei','Chinese Taipei (Taiwan)']:
    li.append(i)
data.continent.replace(li,'Asia',inplace=True)

# %%
data.continent.replace(g.get_group("Australia").country.tolist(),'Australia',inplace=True)

# %%
data.continent.replace(g.get_group("Central America").country.tolist(),'Central America',inplace=True)

# %%
li = g.get_group("Europe").country.tolist()
for i in ["England",'Scotland','Bosnia-Herzegovina', "Wales",'North Macedonia','Northern Ireland','Neukaledonien']:
    li.append(i)
data.continent.replace(li,'Europe',inplace=True)

# %%
li = g.get_group("North America").country.tolist()
li.append('Guadeloupe')
data.continent.replace(li,'North America',inplace=True)

# %%
data.continent.replace(g.get_group("South America").country.tolist(),'South America',inplace=True)

# %%
data.head(60)
# Out:
#                          name            position   age  \
# 0                Amine Gouiri      Centre-Forward  22.0
# 1                  Umar Sadiq      Centre-Forward  25.0
# 2                Carlos Soler    Central Midfield  25.0
# 3               Manuel Akanji         Centre-Back  27.0
# 4                   Wout Faes         Centre-Back  24.0
# 5          Leander Dendoncker  Defensive Midfield  27.0
# 6              Gaëtan Laborde      Centre-Forward  28.0
# 7   Pierre-Emerick Aubameyang      Centre-Forward  33.0
# 8        Jörgen Strand Larsen      Centre-Forward  22.0
# 9               Billy Gilmour    Central Midfield  21.0
# 10               James Garner  Defensive Midfield  21.0
# 11            Duje Caleta-Car         Centre-Back  25.0
# 12             El Bilal Touré      Centre-Forward  20.0
# 13           Christopher Wooh         Centre-Back  20.0
# 14                     Lázaro         Left Winger  20.0
# 15              Idrissa Gueye    Central Midfield  32.0
# 16                   Pep Biel  Attacking Midfield  25.0
# 17               Johan Mojica           Left-Back  30.0
# 18            Carlos Vinícius      Centre-Forward  27.0
# 19                Arthur Melo  Defensive Midfield  26.0
# 20            Wilfried Gnonto      Second Striker  18.0
# 21            Ignatius Ganago      Centre-Forward  23.0
# 22                 Jean Onana  Defensive Midfield  22.0
# 23              Denis Zakaria  Defensive Midfield  25.0
# 24                 Maxi Gómez      Centre-Forward  26.0
# 25                 Adam Ounas        Right Winger  25.0
# 26         Veljko Birmancevic         Left Winger  24.0
# 27                 Willy Boly         Centre-Back  31.0
# 28             Julian Draxler         Left Winger  28.0
# 29                Josh Bowler        Right Winger  23.0
# 30              Aster Vranckx    Central Midfield  19.0
# 31              Willyan Rocha         Centre-Back  27.0
# 32             Gonzalo Melero    Central Midfield  28.0
# 33               Abdou Diallo         Centre-Back  26.0
# 34                Abdul Mumin         Centre-Back  24.0
# 35              Serdar Saatci         Centre-Back  19.0
# 36              Mohamed Sobhi          Goalkeeper  23.0
# 37          Oliver Abildgaard  Defensive Midfield  26.0
# 38           Krzysztof Piatek      Centre-Forward  27.0
# 39               Maryan Shved        Right Winger  25.0
# 40              Yanis Hamache           Left-Back  23.0
# 41            Mohanad Lasheen    Central Midfield  26.0
# 42               Mohamed Reda    Central Midfield  21.0
# 43                 Ahmed Atef      Centre-Forward  24.0
# 44            Kirill Zinovich  Attacking Midfield  19.0
# 45              Davide Veroli         Centre-Back  19.0
# 46                Jack Hendry         Centre-Back  27.0
# 47            Panutche Camara    Central Midfield  25.0
# 48              Vasyl Kravets           Left-Back  25.0
# 49              Ajdin Hrustic  Attacking Midfield  26.0
# 50             Abdoulaye Seck             defence  30.0
# 51              Roman Vantukh           Left-Back  24.0
# 52       Theocharis Tsingaras    Central Midfield  22.0
# 53             Moussa Sissako         Centre-Back  21.0
# 54              Denys Antyukh         Left Winger  25.0
# 55                Aarón Piñán         Left Winger  25.0
# 56               Yassin Marei         Centre-Back  20.0
# 57                 Paul Nardi          Goalkeeper  28.0
# 58             Mahmoud Genesh          Goalkeeper  35.0
# 59          Eduard Bagrintsev        Right Winger  19.0
#
#                      origin_club country_origin_club                new_club  \
# 0                       OGC Nice              France        Stade Rennais FC
# 1                     UD Almería               Spain           Real Sociedad
# 2                    Valencia CF               Spain     Paris Saint-Germain
# 3              Borussia Dortmund             Germany         Manchester City
# 4                    Stade Reims              France          Leicester City
# 5        Wolverhampton Wanderers             England             Aston Villa
# 6               Stade Rennais FC              France                OGC Nice
# 7                   FC Barcelona               Spain              Chelsea FC
# 8                   FC Groningen         Netherlands           Celta de Vigo
# 9                     Chelsea FC             England  Brighton & Hove Albion
# 10         Manchester United U21             England              Everton FC
# 11           Olympique Marseille              France          Southampton FC
# 12                   Stade Reims              France              UD Almería
# 13                       RC Lens              France        Stade Rennais FC
# 14  Clube de Regatas do Flamengo              Brazil              UD Almería
# 15           Paris Saint-Germain              France              Everton FC
# 16                 FC Copenhagen             Denmark      Olympiacos Piraeus
# 17                      Elche CF               Spain           Villarreal CF
# 18                    SL Benfica            Portugal               Fulham FC
# 19                   Juventus FC               Italy            Liverpool FC
# 20                     FC Zürich         Switzerland            Leeds United
# 21                       RC Lens              France               FC Nantes
# 22         FC Girondins Bordeaux              France                 RC Lens
# 23                   Juventus FC               Italy              Chelsea FC
# 24                   Valencia CF               Spain             Trabzonspor
# 25                    SSC Napoli               Italy              LOSC Lille
# 26                      Malmö FF              Sweden             FC Toulouse
# 27       Wolverhampton Wanderers             England       Nottingham Forest
# 28           Paris Saint-Germain              France              SL Benfica
# 29                  Blackpool FC             England       Nottingham Forest
# 30                 VfL Wolfsburg             Germany                AC Milan
# 31               Portimonense SC            Portugal             CSKA Moscow
# 32                    Levante UD               Spain              UD Almería
# 33           Paris Saint-Germain              France              RB Leipzig
# 34          Vitória Guimarães SC            Portugal          Rayo Vallecano
# 35                   Besiktas JK              Turkey                SC Braga
# 36                    Zamalek SC               Egypt               Pharco FC
# 37                   Rubin Kazan              Russia               Celtic FC
# 38                    Hertha BSC             Germany     US Salernitana 1919
# 39                   KV Mechelen             Belgium        Shakhtar Donetsk
# 40                   Boavista FC            Portugal             SK Dnipro-1
# 41              Tala'ea El Gaish               Egypt               Future FC
# 42                 Wadi Degla FC               Egypt               Future FC
# 43                 Wadi Degla FC               Egypt               Future FC
# 44              Lokomotiv Moscow              Russia    Vitória Guimarães SC
# 45          Delfino Pescara 1936               Italy         Cagliari Calcio
# 46                Club Brugge KV             Belgium            US Cremonese
# 47               Plymouth Argyle             England            Ipswich Town
# 48                    CD Leganés               Spain         Vorskla Poltava
# 49           Eintracht Frankfurt             Germany           Hellas Verona
# 50              Royal Antwerp FC             Belgium           Maccabi Haifa
# 51                   Dynamo Kyiv             Ukraine           Zorya Lugansk
# 52             PAOK Thessaloniki              Greece             FC Toulouse
# 53                Standard Liège             Belgium                FC Sochi
# 54                   Dynamo Kyiv             Ukraine           Zorya Lugansk
# 55              Cultural Leonesa               Spain            CF Intercity
# 56                Zamalek SC U21               Egypt               Pharco FC
# 57                    FC Lorient              France                KAA Gent
# 58                    Zamalek SC               Egypt               Future FC
# 59                   CSKA Moscow              Russia    FK Dubnica nad Vahom
#
#    country_new_club        cost      continent
# 0            France  42000000.0         Europe
# 1             Spain  18000000.0         Europe
# 2            France  50000000.0         Europe
# 3           England  30000000.0         Europe
# 4           England  10000000.0         Europe
# 5           England  28000000.0         Europe
# 6            France  18000000.0         Europe
# 7           England  15000000.0         Europe
# 8             Spain   6000000.0         Europe
# 9           England  12000000.0         Europe
# 10          England   7000000.0         Europe
# 11          England  16000000.0         Europe
# 12            Spain   6500000.0         Europe
# 13           France   3000000.0         Europe
# 14            Spain   7000000.0  South America
# 15          England  12000000.0         Europe
# 16           Greece   6000000.0         Europe
# 17            Spain   5000000.0         Europe
# 18          England   8000000.0         Europe
# 19          England  18000000.0         Europe
# 20          England  10000000.0         Europe
# 21           France   5000000.0         Europe
# 22           France   5000000.0         Europe
# 23          England  27000000.0         Europe
# 24           Turkey  12000000.0         Europe
# 25           France   7000000.0         Europe
# 26           France   3500000.0         Europe
# 27          England   6000000.0         Europe
# 28         Portugal  18000000.0         Europe
# 29          England   2000000.0         Europe
# 30            Italy  10000000.0         Europe
# 31           Russia   1500000.0         Europe
# 32            Spain   4000000.0         Europe
# 33          Germany  18000000.0         Europe
# 34            Spain   3000000.0         Europe
# 35         Portugal   1600000.0         Europe
# 36            Egypt    500000.0         africa
# 37         Scotland   7000000.0         Europe
# 38            Italy  12000000.0         Europe
# 39          Ukraine    900000.0         Europe
# 40          Ukraine   2000000.0         Europe
# 41            Egypt    500000.0         africa
# 42            Egypt    150000.0         africa
# 43            Egypt    200000.0         africa
# 44         Portugal    250000.0         Europe
# 45            Italy    200000.0         Europe
# 46            Italy   5000000.0         Europe
# 47          England    450000.0         Europe
# 48          Ukraine   1000000.0         Europe
# 49            Italy   3000000.0         Europe
# 50           Israel   3000000.0         Europe
# 51          Ukraine    400000.0         Europe
# 52           France   1800000.0         Europe
# 53           Russia   1200000.0         Europe
# 54          Ukraine    500000.0         Europe
# 55            Spain    400000.0         Europe
# 56            Egypt     50000.0         africa
# 57          Belgium   2000000.0         Europe
# 58            Egypt    200000.0         africa
# 59         Slovakia    200000.0         Europe

# %%
data.country_origin_club[(data['continent'] != 'africa') & (data['continent'] != 'Antarctica') & (data['continent'] != 'Asia') & (data['continent'] != 'Australia') & (data['continent'] != 'Central America') & (data['continent'] != 'Europe') & (data['continent'] != 'North America') & (data['continent'] != 'South America')].value_counts().index
# Out:
# Index([], dtype='object')

# %% [markdown]
# #

# %%
x

# %%
c = 0
li5 = []
for i in data.country_origin_club.isna():
    if i == True: 
        li5.append(c)
    c+=1

# %%
clubs = []
index = []
for i in li5:
   if data.country_origin_club.loc[i] != "Without Club" and data.origin_club.loc[i] != 'Unknown' and data.origin_club.loc[i] != 'Career break':
        clubs.append(data.origin_club.loc[i])
        index.append(i)
# Out:
# name                    Milán Nemes
# position                  Left-Back
# age                            25.0
# origin_club            Without Club
# country_origin_club             NaN
# new_club                  Putnok FC
# country_new_club            Hungary
# cost                        75000.0
# continent                       NaN
# Name: 155, dtype: object
# name                       Alec Mudimu
# position                   Centre-Back
# age                               27.0
# origin_club               Without Club
# country_origin_club                NaN
# new_club               Caernarfon Town
# country_new_club                 Wales
# cost                          200000.0
# continent                          NaN
# Name: 193, dtype: object
# name                       Stojan Vranjes
# position                         midfield
# age                                  35.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                 FK Sloboda Tuzla
# country_new_club       Bosnia-Herzegovina
# cost                             225000.0
# continent                             NaN
# Name: 526, dtype: object
# name                    Oliver Kragl
# position               Left Midfield
# age                             32.0
# origin_club             Without Club
# country_origin_club              NaN
# new_club                     SV Ried
# country_new_club             Austria
# cost                        500000.0
# continent                        NaN
# Name: 529, dtype: object
# name                    Oguzhan Özyakup
# position               Central Midfield
# age                                29.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club                Fortuna Sittard
# country_new_club            Netherlands
# cost                          1000000.0
# continent                           NaN
# Name: 534, dtype: object
# name                   Gustavo Aprile
# position                Left Midfield
# age                              34.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                      Unknown
# country_new_club                  NaN
# cost                          25000.0
# continent                         NaN
# Name: 542, dtype: object
# name                   Gustavo Carbonieri
# position                      Centre-Back
# age                                  30.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                       FBC Casale
# country_new_club                    Italy
# cost                             100000.0
# continent                             NaN
# Name: 547, dtype: object
# name                   Florian Grillitsch
# position               Defensive Midfield
# age                                  27.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                   Ajax Amsterdam
# country_new_club              Netherlands
# cost                           16000000.0
# continent                             NaN
# Name: 550, dtype: object
# name                       Stephane Acka
# position                     Centre-Back
# age                                 31.0
# origin_club                 Without Club
# country_origin_club                  NaN
# new_club               Sekzia Ness Ziona
# country_new_club                  Israel
# cost                            300000.0
# continent                            NaN
# Name: 565, dtype: object
# name                                    Loris Tinelli
# position                                 Right Winger
# age                                              23.0
# origin_club                              Without Club
# country_origin_club                               NaN
# new_club               Yokohama Sports & Culture Club
# country_new_club                                Japan
# cost                                         125000.0
# continent                                         NaN
# Name: 572, dtype: object
# name                              Ilya Zhigulev
# position                       Central Midfield
# age                                        26.0
# origin_club                        Without Club
# country_origin_club                         NaN
# new_club               FC Pari Nizhniy Novgorod
# country_new_club                         Russia
# cost                                   750000.0
# continent                                   NaN
# Name: 585, dtype: object
# name                     Mamadou Diarra
# position                    Centre-Back
# age                                24.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               Grenoble Foot 38
# country_new_club                 France
# cost                          1200000.0
# continent                           NaN
# Name: 586, dtype: object
# name                        Alexandre Dujardin
# position                           Centre-Back
# age                                       23.0
# origin_club                       Without Club
# country_origin_club                        NaN
# new_club               Hong Kong Football Club
# country_new_club                      Hongkong
# cost                                   10000.0
# continent                                  NaN
# Name: 587, dtype: object
# name                    Kareem Isiaka
# position               Centre-Forward
# age                              21.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                  Arbroath FC
# country_new_club             Scotland
# cost                          50000.0
# continent                         NaN
# Name: 620, dtype: object
# name                        Eric Appiah
# position                   Right Winger
# age                                21.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               Olympias Lympion
# country_new_club                 Cyprus
# cost                            50000.0
# continent                           NaN
# Name: 845, dtype: object
# name                            Zhi Zheng
# position               Defensive Midfield
# age                                  42.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                     Guangzhou FC
# country_new_club                    China
# cost                              25000.0
# continent                             NaN
# Name: 1081, dtype: object
# name                   Marco Schönbächler
# position                    Left Midfield
# age                                  32.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                        FC Urdorf
# country_new_club              Switzerland
# cost                             200000.0
# continent                             NaN
# Name: 1084, dtype: object
# name                     Uros Korun
# position                Centre-Back
# age                            35.0
# origin_club            Without Club
# country_origin_club             NaN
# new_club                NK Radomlje
# country_new_club           Slovenia
# cost                        50000.0
# continent                       NaN
# Name: 1087, dtype: object
# name                   Cristian Battocchio
# position                  Central Midfield
# age                                   30.0
# origin_club                   Without Club
# country_origin_club                    NaN
# new_club                         Volos NPS
# country_new_club                    Greece
# cost                             1500000.0
# continent                              NaN
# Name: 1093, dtype: object
# name                          Bowen Huang
# position               Defensive Midfield
# age                                  35.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                     Guangzhou FC
# country_new_club                    China
# cost                              50000.0
# continent                             NaN
# Name: 1095, dtype: object
# name                   Chenglin Zhang
# position                    Left-Back
# age                              35.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                 Guangzhou FC
# country_new_club                China
# cost                          50000.0
# continent                         NaN
# Name: 1096, dtype: object
# name                     Henritse Eninful
# position               Defensive Midfield
# age                                  30.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                        URSL Visé
# country_new_club                  Belgium
# cost                             150000.0
# continent                             NaN
# Name: 1099, dtype: object
# name                   Stratos Chintzidis
# position                        Left-Back
# age                                  34.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                       PAE Chania
# country_new_club                   Greece
# cost                             100000.0
# continent                             NaN
# Name: 1105, dtype: object
# name                           Shalva Ogbaidze
# position                          Right Winger
# age                                       20.0
# origin_club                       Without Club
# country_origin_club                        NaN
# new_club               FC Viktoria 1889 Berlin
# country_new_club                       Germany
# cost                                  100000.0
# continent                                  NaN
# Name: 1126, dtype: object
# name                   Junior Kabananga
# position                 Centre-Forward
# age                                33.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club                     CS Mioveni
# country_new_club                Romania
# cost                           275000.0
# continent                           NaN
# Name: 1184, dtype: object
# name                    Alexandre Castaing
# position                Defensive Midfield
# age                                   25.0
# origin_club                   Without Club
# country_origin_club                    NaN
# new_club               Canet Roussillon FC
# country_new_club                    France
# cost                               25000.0
# continent                              NaN
# Name: 1255, dtype: object
# name                   Matheus Dantas
# position                  Centre-Back
# age                              23.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                PO Xylotymbou
# country_new_club               Cyprus
# cost                         250000.0
# continent                         NaN
# Name: 1270, dtype: object
# name                    Álvaro Martí
# position                    midfield
# age                             19.0
# origin_club             Without Club
# country_origin_club              NaN
# new_club               PE Sant Jordi
# country_new_club               Spain
# cost                         10000.0
# continent                        NaN
# Name: 1386, dtype: object
# name                       Daichi Inui
# position                   Centre-Back
# age                               32.0
# origin_club               Without Club
# country_origin_club                NaN
# new_club               Nagano Parceiro
# country_new_club                 Japan
# cost                          200000.0
# continent                          NaN
# Name: 1395, dtype: object
# name                   Hüseyin Yilmaz
# position                   Goalkeeper
# age                              26.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club               Kirklarelispor
# country_new_club               Turkey
# cost                          50000.0
# continent                         NaN
# Name: 1397, dtype: object
# name                      Ença Fati
# position               Right Winger
# age                            29.0
# origin_club            Without Club
# country_origin_club             NaN
# new_club                   CD Mafra
# country_new_club           Portugal
# cost                       200000.0
# continent                       NaN
# Name: 1398, dtype: object
# name                            Vander
# position                   Left Winger
# age                               33.0
# origin_club               Without Club
# country_origin_club                NaN
# new_club               Ethnikos Achnas
# country_new_club                Cyprus
# cost                          300000.0
# continent                          NaN
# Name: 1436, dtype: object
# name                                   Yanis Mbombo
# position                             Centre-Forward
# age                                            28.0
# origin_club                            Without Club
# country_origin_club                             NaN
# new_club               ACS FC Brasov Steagu Renaste
# country_new_club                            Romania
# cost                                       150000.0
# continent                                       NaN
# Name: 1451, dtype: object
# name                      Xiaofei Deng
# position                    Goalkeeper
# age                               39.0
# origin_club               Without Club
# country_origin_club                NaN
# new_club               Ji'nan Xingzhou
# country_new_club                 China
# cost                          100000.0
# continent                          NaN
# Name: 1576, dtype: object
# name                   Alberto Libertazzi
# position                   Centre-Forward
# age                                  30.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                ASD Chieri Calcio
# country_new_club                    Italy
# cost                              50000.0
# continent                             NaN
# Name: 1579, dtype: object
# name                                Bari Mamatil
# position                            Right Winger
# age                                         32.0
# origin_club                         Without Club
# country_origin_club                          NaN
# new_club               Xinjiang Tianshan Leopard
# country_new_club                           China
# cost                                     75000.0
# continent                                    NaN
# Name: 1584, dtype: object
# name                           Nassim Hnid
# position                       Centre-Back
# age                                   25.0
# origin_club                   Without Club
# country_origin_club                    NaN
# new_club               Olympique Khouribga
# country_new_club                   Morocco
# cost                              650000.0
# continent                              NaN
# Name: 1594, dtype: object
# name                    Osayamen Osawe
# position                Centre-Forward
# age                               28.0
# origin_club               Without Club
# country_origin_club                NaN
# new_club               FC Halifax Town
# country_new_club               England
# cost                          200000.0
# continent                          NaN
# Name: 1771, dtype: object
# name                         Jabar Sharza
# position               Attacking Midfield
# age                                  28.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                        Ariana FC
# country_new_club                   Sweden
# cost                             200000.0
# continent                             NaN
# Name: 1773, dtype: object
# name                              Joseph Mensah
# position                           Right Winger
# age                                        27.0
# origin_club                        Without Club
# country_origin_club                         NaN
# new_club               FK Otrant-Olympic Ulcinj
# country_new_club                     Montenegro
# cost                                    50000.0
# continent                                   NaN
# Name: 1954, dtype: object
# name                   Vasco Regini
# position                  Left-Back
# age                            31.0
# origin_club            Without Club
# country_origin_club             NaN
# new_club                  Rimini FC
# country_new_club              Italy
# cost                       300000.0
# continent                       NaN
# Name: 2009, dtype: object
# name                     Ivan Lendric
# position               Centre-Forward
# age                              31.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                FC Rupel Boom
# country_new_club              Belgium
# cost                         250000.0
# continent                         NaN
# Name: 2012, dtype: object
# name                   Cristian Tello
# position                  Left Winger
# age                              31.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club               Los Angeles FC
# country_new_club        United States
# cost                        5000000.0
# continent                         NaN
# Name: 2013, dtype: object
# name                      Omar Rababah
# position                      midfield
# age                               30.0
# origin_club               Without Club
# country_origin_club                NaN
# new_club               Fgura United FC
# country_new_club                 Malta
# cost                           10000.0
# continent                          NaN
# Name: 2017, dtype: object
# name                        Beichen Qin
# position                   Right Winger
# age                                29.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               Wuhan Jiangcheng
# country_new_club                  China
# cost                            25000.0
# continent                           NaN
# Name: 2018, dtype: object
# name                           Yerjet Yerzat
# position                          Goalkeeper
# age                                     29.0
# origin_club                     Without Club
# country_origin_club                      NaN
# new_club               Heilongjiang Ice City
# country_new_club                       China
# cost                                100000.0
# continent                                NaN
# Name: 2019, dtype: object
# name                   Cameron Hogg
# position                 Goalkeeper
# age                            27.0
# origin_club            Without Club
# country_origin_club             NaN
# new_club                FK Pohronie
# country_new_club           Slovakia
# cost                       100000.0
# continent                       NaN
# Name: 2021, dtype: object
# name                   Alessandro Raimo
# position                     Right-Back
# age                                23.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club                 ACR Siena 1904
# country_new_club                  Italy
# cost                           150000.0
# continent                           NaN
# Name: 2027, dtype: object
# name                                  Hanchen Shi
# position                                 midfield
# age                                          26.0
# origin_club                          Without Club
# country_origin_club                           NaN
# new_club               Inner Mongolia Caoshangfei
# country_new_club                            China
# cost                                      75000.0
# continent                                     NaN
# Name: 2033, dtype: object
# name                     Yushi Mizobuchi
# position                      Right-Back
# age                                 28.0
# origin_club                 Without Club
# country_origin_club                  NaN
# new_club               Kamatamare Sanuki
# country_new_club                   Japan
# cost                            225000.0
# continent                            NaN
# Name: 2035, dtype: object
# name                    Magomed Rabadanov
# position               Attacking Midfield
# age                                  20.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                     FK Essentuki
# country_new_club                   Russia
# cost                             100000.0
# continent                             NaN
# Name: 2037, dtype: object
# name                   Vilius Armalas
# position                  Centre-Back
# age                              22.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                 FC Hegelmann
# country_new_club            Lithuania
# cost                         175000.0
# continent                         NaN
# Name: 2038, dtype: object
# name                                      Wesley Soares
# position                               Central Midfield
# age                                                24.0
# origin_club                                Without Club
# country_origin_club                                 NaN
# new_club               Clube Náutico Marcílio Dias (SC)
# country_new_club                                 Brazil
# cost                                           250000.0
# continent                                           NaN
# Name: 2040, dtype: object
# name                      Ibba Laajab
# position               Centre-Forward
# age                              37.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                       FK Lyn
# country_new_club               Norway
# cost                         200000.0
# continent                         NaN
# Name: 2305, dtype: object
# name                          Carlos Lizarazo
# position                   Attacking Midfield
# age                                      31.0
# origin_club                      Without Club
# country_origin_club                       NaN
# new_club               Independiente Santa Fe
# country_new_club                     Colombia
# cost                                 200000.0
# continent                                 NaN
# Name: 2308, dtype: object
# name                      Francesco Nicastro
# position                        Right Winger
# age                                     30.0
# origin_club                     Without Club
# country_origin_club                      NaN
# new_club               US Città di Pontedera
# country_new_club                       Italy
# cost                                250000.0
# continent                                NaN
# Name: 2310, dtype: object
# name                                   Murilo Rangel
# position                                Right Winger
# age                                             31.0
# origin_club                             Without Club
# country_origin_club                              NaN
# new_club               Esporte Clube Água Santa (SP)
# country_new_club                              Brazil
# cost                                        300000.0
# continent                                        NaN
# Name: 2311, dtype: object
# name                                 Cevat Kuy
# position                            Right-Back
# age                                       28.0
# origin_club                       Without Club
# country_origin_club                        NaN
# new_club               Bayburt Özel Idare Spor
# country_new_club                        Turkey
# cost                                   25000.0
# continent                                  NaN
# Name: 2312, dtype: object
# name                              Mukwelle Akale
# position                            Right Winger
# age                                         25.0
# origin_club                         Without Club
# country_origin_club                          NaN
# new_club               South Georgia Tormenta FC
# country_new_club                   United States
# cost                                    100000.0
# continent                                    NaN
# Name: 2313, dtype: object
# name                             Ilias Moutha-Sebtaoui
# position                                    Goalkeeper
# age                                               23.0
# origin_club                               Without Club
# country_origin_club                                NaN
# new_club               Royale Union Saint Gilloise U23
# country_new_club                               Belgium
# cost                                           50000.0
# continent                                          NaN
# Name: 2315, dtype: object
# name                             Vojin Savic
# position                          Goalkeeper
# age                                     22.0
# origin_club                     Without Club
# country_origin_club                      NaN
# new_club               FK Buducnost Banovici
# country_new_club          Bosnia-Herzegovina
# cost                                 50000.0
# continent                                NaN
# Name: 2316, dtype: object
# name                        Henry Castillo
# position                    Centre-Forward
# age                                   28.0
# origin_club                   Without Club
# country_origin_club                    NaN
# new_club               Jaguares de Córdoba
# country_new_club                  Colombia
# cost                              150000.0
# continent                              NaN
# Name: 2318, dtype: object
# name                   Joao William
# position                Centre-Back
# age                            26.0
# origin_club            Without Club
# country_origin_club             NaN
# new_club                FK Riteriai
# country_new_club          Lithuania
# cost                       150000.0
# continent                       NaN
# Name: 2322, dtype: object
# name                                  Caio Emerson
# position                            Centre-Forward
# age                                           23.0
# origin_club                           Without Club
# country_origin_club                            NaN
# new_club               Club Polideportivo El Ejido
# country_new_club                             Spain
# cost                                      100000.0
# continent                                      NaN
# Name: 2412, dtype: object
# name                   Houssine Khoukhouche
# position                   Central Midfield
# age                                    29.0
# origin_club                    Without Club
# country_origin_club                     NaN
# new_club                  Olympique Dcheira
# country_new_club                    Morocco
# cost                               125000.0
# continent                               NaN
# Name: 2422, dtype: object
# name                           Yagya Kapoor
# position                          Left-Back
# age                                    23.0
# origin_club                    Without Club
# country_origin_club                     NaN
# new_club               RoundGlass Punjab FC
# country_new_club                      India
# cost                                25000.0
# continent                               NaN
# Name: 2442, dtype: object
# name                         Damian Herth
# position               Defensive Midfield
# age                                  20.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                   VfR Groß-Gerau
# country_new_club                  Germany
# cost                              50000.0
# continent                             NaN
# Name: 2520, dtype: object
# name                       Martín Cáceres
# position                      Centre-Back
# age                                  35.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club               Los Angeles Galaxy
# country_new_club            United States
# cost                             900000.0
# continent                             NaN
# Name: 2541, dtype: object
# name                   Rodrigo Cabrera
# position                   Centre-Back
# age                               33.0
# origin_club               Without Club
# country_origin_club                NaN
# new_club                      CA Fénix
# country_new_club               Uruguay
# cost                          250000.0
# continent                          NaN
# Name: 2542, dtype: object
# name                        Tongo Doumbia
# position               Defensive Midfield
# age                                  33.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                Western United FC
# country_new_club                Australia
# cost                             100000.0
# continent                             NaN
# Name: 2543, dtype: object
# name                   Oktay Demircan
# position                   Right-Back
# age                              33.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                   Bulvarspor
# country_new_club               Turkey
# cost                          25000.0
# continent                         NaN
# Name: 2546, dtype: object
# name                    William Jebor
# position               Centre-Forward
# age                              30.0
# origin_club              Career break
# country_origin_club               NaN
# new_club                     Kalju FC
# country_new_club              Estonia
# cost                         200000.0
# continent                         NaN
# Name: 2548, dtype: object
# name                   Lukas Hupfauf
# position                  Right-Back
# age                             25.0
# origin_club             Without Club
# country_origin_club              NaN
# new_club               FSV Frankfurt
# country_new_club             Germany
# cost                        200000.0
# continent                        NaN
# Name: 2553, dtype: object
# name                        Nassim Yettou
# position               Defensive Midfield
# age                                  30.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                         ES Sétif
# country_new_club                  Algeria
# cost                             350000.0
# continent                             NaN
# Name: 2554, dtype: object
# name                    Maksym Marusych
# position                 Centre-Forward
# age                                29.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               Ingulets Petrove
# country_new_club                Ukraine
# cost                           225000.0
# continent                           NaN
# Name: 2557, dtype: object
# name                     Godwin Chika
# position               Centre-Forward
# age                              24.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                     ES Sétif
# country_new_club              Algeria
# cost                         175000.0
# continent                         NaN
# Name: 2563, dtype: object
# name                     Hamza Cetinkaya
# position                     Centre-Back
# age                                 21.0
# origin_club                 Without Club
# country_origin_club                  NaN
# new_club               SSV Reutlingen 05
# country_new_club                 Germany
# cost                             50000.0
# continent                            NaN
# Name: 2564, dtype: object
# name                   Burak Bozdemir
# position                  Left Winger
# age                              25.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                     Varde IF
# country_new_club              Denmark
# cost                          25000.0
# continent                         NaN
# Name: 2569, dtype: object
# name                             Jun Wang
# position               Attacking Midfield
# age                                  32.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                 Yanbian Longding
# country_new_club                    China
# cost                              50000.0
# continent                             NaN
# Name: 2612, dtype: object
# name                       Fedi Ben Choug
# position               Attacking Midfield
# age                                  27.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                Hassania d'Agadir
# country_new_club                  Morocco
# cost                             300000.0
# continent                             NaN
# Name: 2659, dtype: object
# name                            Dilyar Hoshurjan
# position                              Goalkeeper
# age                                         20.0
# origin_club                         Without Club
# country_origin_club                          NaN
# new_club               Chengdu Rongcheng Reserve
# country_new_club                           China
# cost                                     10000.0
# continent                                    NaN
# Name: 2727, dtype: object
# name                   Nicholas Osei Bonsu
# position                Attacking Midfield
# age                                   21.0
# origin_club                        Unknown
# country_origin_club                    NaN
# new_club                  Asante Kotoko SC
# country_new_club                     Ghana
# cost                               25000.0
# continent                              NaN
# Name: 2739, dtype: object
# name                                         NaN
# position                              Right-Back
# age                                         25.0
# origin_club                         Without Club
# country_origin_club                          NaN
# new_club               University of Pretoria FC
# country_new_club                    South Africa
# cost                                     25000.0
# continent                                    NaN
# Name: 2753, dtype: object
# name                               Jádson
# position               Attacking Midfield
# age                                  38.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                          Retired
# country_new_club                      NaN
# cost                             350000.0
# continent                             NaN
# Name: 2794, dtype: object
# name                      Igor Chaykovskyi
# position                Defensive Midfield
# age                                   30.0
# origin_club                   Without Club
# country_origin_club                    NaN
# new_club               Bukovyna Chernivtsi
# country_new_club                   Ukraine
# cost                              200000.0
# continent                              NaN
# Name: 2797, dtype: object
# name                          Ahmed Magdy
# position               Defensive Midfield
# age                                  33.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                         Petrojet
# country_new_club                    Egypt
# cost                             150000.0
# continent                             NaN
# Name: 2798, dtype: object
# name                        Deniz Cinar
# position                     Goalkeeper
# age                                29.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               Nigde Anadolu FK
# country_new_club                 Turkey
# cost                            25000.0
# continent                           NaN
# Name: 2799, dtype: object
# name                               Yu Zhang
# position                        Centre-Back
# age                                    28.0
# origin_club                    Without Club
# country_origin_club                     NaN
# new_club               Qingdao Youth Island
# country_new_club                      China
# cost                               100000.0
# continent                               NaN
# Name: 2800, dtype: object
# name                   Yves Simon Pambou
# position                Central Midfield
# age                                 26.0
# origin_club                 Without Club
# country_origin_club                  NaN
# new_club                Metalist Kharkiv
# country_new_club                 Ukraine
# cost                             50000.0
# continent                            NaN
# Name: 2801, dtype: object
# name                                Nacho Gil
# position                          Left Winger
# age                                      26.0
# origin_club                      Without Club
# country_origin_club                       NaN
# new_club               New England Revolution
# country_new_club                United States
# cost                                 300000.0
# continent                                 NaN
# Name: 2804, dtype: object
# name                         Dylan George
# position                      Left Winger
# age                                  24.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club               SC Eendracht Aalst
# country_new_club                  Belgium
# cost                              10000.0
# continent                             NaN
# Name: 2806, dtype: object
# name                    Franco Thomas
# position                   Goalkeeper
# age                              29.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club               GS Mazara 1946
# country_new_club                Italy
# cost                         100000.0
# continent                         NaN
# Name: 2810, dtype: object
# name                       Andriy Yakymiv
# position               Defensive Midfield
# age                                  25.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                         PFK Lviv
# country_new_club                  Ukraine
# cost                              50000.0
# continent                             NaN
# Name: 2812, dtype: object
# name                          Serhat Yesilördek
# position                       Central Midfield
# age                                        23.0
# origin_club                        Without Club
# country_origin_club                         NaN
# new_club               68 Aksaray Belediye Spor
# country_new_club                         Turkey
# cost                                    25000.0
# continent                                   NaN
# Name: 2816, dtype: object
# name                      Haoran Li
# position                Left Winger
# age                            22.0
# origin_club            Without Club
# country_origin_club             NaN
# new_club                 NK Sesvete
# country_new_club            Croatia
# cost                        50000.0
# continent                       NaN
# Name: 2817, dtype: object
# name                         Kaan Kirci
# position                    Left Winger
# age                                21.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               Nigde Anadolu FK
# country_new_club                 Turkey
# cost                            25000.0
# continent                           NaN
# Name: 2821, dtype: object
# name                          Borna Gilja
# position               Attacking Midfield
# age                                  22.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                       NK Ravnice
# country_new_club                  Croatia
# cost                              25000.0
# continent                             NaN
# Name: 2823, dtype: object
# name                   Yagiz Efe Zeybek
# position                      Left-Back
# age                                19.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               Nigde Anadolu FK
# country_new_club                 Turkey
# cost                            10000.0
# continent                           NaN
# Name: 2824, dtype: object
# name                           Houssem Gatfia
# position                   Attacking Midfield
# age                                      23.0
# origin_club                           Unknown
# country_origin_club                       NaN
# new_club               Avenir Sportif Rejiche
# country_new_club                      Tunisia
# cost                                  25000.0
# continent                                 NaN
# Name: 2899, dtype: object
# name                       Ilyas Cakmak
# position                 Centre-Forward
# age                                34.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               Viven Bornova FK
# country_new_club                 Turkey
# cost                            50000.0
# continent                           NaN
# Name: 3009, dtype: object
# name                     Sajjad Moshkelpour
# position                        Centre-Back
# age                                    32.0
# origin_club                    Without Club
# country_origin_club                     NaN
# new_club               Omid Vahdat Khorasan
# country_new_club                       Iran
# cost                               100000.0
# continent                               NaN
# Name: 3013, dtype: object
# name                         Ben Sitelkol
# position                        Left-Back
# age                                  30.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club               Hapoel Kfar Shalem
# country_new_club                   Israel
# cost                             100000.0
# continent                             NaN
# Name: 3014, dtype: object
# name                      Hamed Fallahzadeh
# position                         Goalkeeper
# age                                    35.0
# origin_club                    Without Club
# country_origin_club                     NaN
# new_club               Omid Vahdat Khorasan
# country_new_club                       Iran
# cost                                50000.0
# continent                               NaN
# Name: 3017, dtype: object
# name                   Faycal Rherras
# position                    Left-Back
# age                              29.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                    URSL Visé
# country_new_club              Belgium
# cost                         250000.0
# continent                         NaN
# Name: 3020, dtype: object
# name                      Evan Louro
# position                  Goalkeeper
# age                             26.0
# origin_club             Without Club
# country_origin_club              NaN
# new_club               FC Cincinnati
# country_new_club       United States
# cost                        275000.0
# continent                        NaN
# Name: 3023, dtype: object
# name                         Thaer Krouma
# position               Defensive Midfield
# age                                  32.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                           Al-Ain
# country_new_club             Saudi Arabia
# cost                             250000.0
# continent                             NaN
# Name: 3142, dtype: object
# name                       Nicholas Nasini
# position                       Left Winger
# age                                   23.0
# origin_club                   Without Club
# country_origin_club                    NaN
# new_club               Sancataldese Calcio
# country_new_club                     Italy
# cost                               10000.0
# continent                              NaN
# Name: 3222, dtype: object
# name                             Artem Dudik
# position                        Right Winger
# age                                     25.0
# origin_club                     Without Club
# country_origin_club                      NaN
# new_club               Metalist 1925 Kharkiv
# country_new_club                     Ukraine
# cost                                125000.0
# continent                                NaN
# Name: 3223, dtype: object
# name                      Raul Torregrossa
# position                    Centre-Forward
# age                                   22.0
# origin_club                   Without Club
# country_origin_club                    NaN
# new_club               Sancataldese Calcio
# country_new_club                     Italy
# cost                               50000.0
# continent                              NaN
# Name: 3224, dtype: object
# name                              Cássio
# position                     Centre-Back
# age                                 32.0
# origin_club                 Without Club
# country_origin_club                  NaN
# new_club               Hong Kong Rangers
# country_new_club                Hongkong
# cost                            150000.0
# continent                            NaN
# Name: 3473, dtype: object
# name                     Daniel Keita-Ruel
# position                    Centre-Forward
# age                                   32.0
# origin_club                   Without Club
# country_origin_club                    NaN
# new_club               SV Waldhof Mannheim
# country_new_club                   Germany
# cost                              300000.0
# continent                              NaN
# Name: 3709, dtype: object
# name                        Karrar Jassim
# position               Attacking Midfield
# age                                  35.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                Naft Al-Wassat SC
# country_new_club                     Iraq
# cost                             150000.0
# continent                             NaN
# Name: 3710, dtype: object
# name                   Yevgen Troyanovskyi
# position                     Left Midfield
# age                                   29.0
# origin_club                   Without Club
# country_origin_club                    NaN
# new_club                  Wisla Sandomierz
# country_new_club                    Poland
# cost                              100000.0
# continent                              NaN
# Name: 3712, dtype: object
# name                   Shaft Brewer Jr.
# position                     Right-Back
# age                                22.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club                    Union Omaha
# country_new_club          United States
# cost                            50000.0
# continent                           NaN
# Name: 3720, dtype: object
# name                         Eduardo Baldé
# position                    Centre-Forward
# age                                   23.0
# origin_club                   Without Club
# country_origin_club                    NaN
# new_club               Termoli Calcio 1920
# country_new_club                     Italy
# cost                               25000.0
# continent                              NaN
# Name: 3723, dtype: object
# name                   Polidoro Junior
# position                   Centre-Back
# age                               25.0
# origin_club               Without Club
# country_origin_club                NaN
# new_club                       US Ivry
# country_new_club                France
# cost                          175000.0
# continent                          NaN
# Name: 3814, dtype: object
# name                   Aleksandar Tasic
# position                     Right-Back
# age                                23.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club                    OFK Beograd
# country_new_club                 Serbia
# cost                            50000.0
# continent                           NaN
# Name: 3819, dtype: object
# name                   Luiz Ferreira
# position                      attack
# age                             24.0
# origin_club                  Unknown
# country_origin_club              NaN
# new_club                   Diyala FC
# country_new_club                Iraq
# cost                         25000.0
# continent                        NaN
# Name: 3862, dtype: object
# name                                      Hrvoje Milic
# position                                     Left-Back
# age                                               33.0
# origin_club                               Without Club
# country_origin_club                                NaN
# new_club               NK Zrinski Jurjevac Punitovacki
# ...
# name                   Yassan Ouatching
# position                 Centre-Forward
# age                                23.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club                  Hearts of Oak
# country_new_club                  Ghana
# cost                            75000.0
# continent                           NaN
# Name: 31939, dtype: object
# name                                    Mehmet Arslan
# position                           Attacking Midfield
# age                                              24.0
# origin_club                              Without Club
# country_origin_club                               NaN
# new_club               Marignane-Gignac-Côte-Bleue FC
# country_new_club                               France
# cost                                         100000.0
# continent                                         NaN
# Name: 31956, dtype: object
# name                   Dominykas Jakociunas
# position                     Centre-Forward
# age                                    19.0
# origin_club                    Career break
# country_origin_club                     NaN
# new_club                 FK Minija Kretinga
# country_new_club                  Lithuania
# cost                                25000.0
# continent                               NaN
# Name: 32034, dtype: object
# name                   Quinten Huybers
# position                   Centre-Back
# age                               20.0
# origin_club               Without Club
# country_origin_club                NaN
# new_club                 SV Unitas '59
# country_new_club           Netherlands
# cost                           50000.0
# continent                          NaN
# Name: 32087, dtype: object
# name                   Iván Torreblanca
# position                     Right-Back
# age                                21.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club                       FE Grama
# country_new_club                  Spain
# cost                            50000.0
# continent                           NaN
# Name: 32170, dtype: object
# name                   Erick Noriega
# position                 Centre-Back
# age                             20.0
# origin_club             Without Club
# country_origin_club              NaN
# new_club                 SV Straelen
# country_new_club             Germany
# cost                         50000.0
# continent                        NaN
# Name: 32320, dtype: object
# name                          Vasil Parvanov
# position                  Defensive Midfield
# age                                     20.0
# origin_club                     Without Club
# country_origin_club                      NaN
# new_club               Lokomotiv Mezdra 2012
# country_new_club                    Bulgaria
# cost                                 10000.0
# continent                                NaN
# Name: 32363, dtype: object
# name                            Robert Raducioiu
# position                             Centre-Back
# age                                         18.0
# origin_club                         Without Club
# country_origin_club                          NaN
# new_club               Sepsi OSK Sf. Gheorghe II
# country_new_club                         Romania
# cost                                     10000.0
# continent                                    NaN
# Name: 32376, dtype: object
# name                     Younes Ben Hammou
# position                       Left Winger
# age                                   21.0
# origin_club                   Without Club
# country_origin_club                    NaN
# new_club               Olympia SC Wijgmaal
# country_new_club                   Belgium
# cost                               50000.0
# continent                              NaN
# Name: 32383, dtype: object
# name                      Ousmane Faye
# position                Centre-Forward
# age                               23.0
# origin_club               Without Club
# country_origin_club                NaN
# new_club               Gandzasar Kapan
# country_new_club               Armenia
# cost                           25000.0
# continent                          NaN
# Name: 32395, dtype: object
# name                             Baris Can Öztürk
# position                               Right-Back
# age                                          20.0
# origin_club                          Without Club
# country_origin_club                           NaN
# new_club               Civil Service Strollers FC
# country_new_club                         Scotland
# cost                                      75000.0
# continent                                     NaN
# Name: 32417, dtype: object
# name                          Ange Belibi
# position               Attacking Midfield
# age                                  20.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                Pietà Hotspurs FC
# country_new_club                    Malta
# cost                              75000.0
# continent                             NaN
# Name: 32428, dtype: object
# name                      Héctor Solano
# position                  Left Midfield
# age                                23.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               Cúcuta Deportivo
# country_new_club               Colombia
# cost                           300000.0
# continent                           NaN
# Name: 32450, dtype: object
# name                      Syariful Haq
# position                       defence
# age                               20.0
# origin_club               Without Club
# country_origin_club                NaN
# new_club               Simei United FC
# country_new_club             Singapore
# cost                           25000.0
# continent                          NaN
# Name: 32453, dtype: object
# name                       Dennis Ramírez
# position               Attacking Midfield
# age                                  20.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                      Antigua GFC
# country_new_club                Guatemala
# cost                              25000.0
# continent                             NaN
# Name: 32470, dtype: object
# name                        Abdula Genaev
# position               Attacking Midfield
# age                                  21.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                    SV Hemelingen
# country_new_club                  Germany
# cost                              50000.0
# continent                             NaN
# Name: 32529, dtype: object
# name                      Wilson Pineda
# position                       midfield
# age                                31.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               CD Suchitepéquez
# country_new_club              Guatemala
# cost                           100000.0
# continent                           NaN
# Name: 32534, dtype: object
# name                   Ozkan Cetiner
# position                    midfield
# age                             21.0
# origin_club             Without Club
# country_origin_club              NaN
# new_club                   AC Amiens
# country_new_club              France
# cost                        150000.0
# continent                        NaN
# Name: 32620, dtype: object
# name                   Khalid Mubarak
# position                  Centre-Back
# age                              23.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                 Al-Shamal SC
# country_new_club                Qatar
# cost                          25000.0
# continent                         NaN
# Name: 32738, dtype: object
# name                    Guilain Zrankeon
# position                     Centre-Back
# age                                 20.0
# origin_club                 Without Club
# country_origin_club                  NaN
# new_club               Valenciennes FC B
# country_new_club                  France
# cost                             25000.0
# continent                            NaN
# Name: 32757, dtype: object
# name                             Nathaniel Amoah
# position                              Right-Back
# age                                         20.0
# origin_club                         Without Club
# country_origin_club                          NaN
# new_club               Patro Eisden Maasmechelen
# country_new_club                         Belgium
# cost                                     25000.0
# continent                                    NaN
# Name: 32764, dtype: object
# name                          Nyoman Aro
# position                     Centre-Back
# age                                 21.0
# origin_club                 Without Club
# country_origin_club                  NaN
# new_club               PSDS Deli Serdang
# country_new_club               Indonesia
# cost                             25000.0
# continent                            NaN
# Name: 32789, dtype: object
# name                    Thierry Kassi
# position               Centre-Forward
# age                              22.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                 ASEC Mimosas
# country_new_club        Cote d'Ivoire
# cost                         125000.0
# continent                         NaN
# Name: 32829, dtype: object
# name                     Amar Meljichi
# position                    Goalkeeper
# age                               20.0
# origin_club               Without Club
# country_origin_club                NaN
# new_club                     FC Shkupi
# country_new_club       North Macedonia
# cost                           10000.0
# continent                          NaN
# Name: 32841, dtype: object
# name                   Momchil Kuzmanov
# position                    Left Winger
# age                                19.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club                 Spartak Pleven
# country_new_club               Bulgaria
# cost                            25000.0
# continent                           NaN
# Name: 32888, dtype: object
# name                            Diego
# position                  Centre-Back
# age                              23.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club               Santa Lucia FC
# country_new_club                Malta
# cost                          50000.0
# continent                         NaN
# Name: 32920, dtype: object
# name                   Vladislav Loshkarev
# position                        Goalkeeper
# age                                   18.0
# origin_club                   Without Club
# country_origin_club                    NaN
# new_club                    Shakhter-Bulat
# country_new_club                Kazakhstan
# cost                               50000.0
# continent                              NaN
# Name: 32924, dtype: object
# name                        David Davtyan
# position               Attacking Midfield
# age                                  20.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                  KMSK Deinze U21
# country_new_club                  Belgium
# cost                              10000.0
# continent                             NaN
# Name: 32925, dtype: object
# name                      Ivan Ivanov
# position               Centre-Forward
# age                              25.0
# origin_club              Without Club
# country_origin_club               NaN
# new_club                   Kyustendil
# country_new_club             Bulgaria
# cost                          10000.0
# continent                         NaN
# Name: 32954, dtype: object
# name                   Naoufal Azzagari
# position                   Right Winger
# age                                20.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club                RFC Seraing U23
# country_new_club                Belgium
# cost                            50000.0
# continent                           NaN
# Name: 33004, dtype: object
# name                        Olaoluwa Ojetunde
# position                       Centre-Forward
# age                                      19.0
# origin_club                      Without Club
# country_origin_club                       NaN
# new_club               Lernayin Artsakh Goris
# country_new_club                      Armenia
# cost                                  50000.0
# continent                                 NaN
# Name: 33008, dtype: object
# name                      Chris Rumbiak
# position                   Right Winger
# age                                21.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               Perserang Serang
# country_new_club              Indonesia
# cost                            50000.0
# continent                           NaN
# Name: 33019, dtype: object
# name                      Gia Apkhazava
# position                   Right Winger
# age                                19.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               Shukura Kobuleti
# country_new_club                Georgia
# cost                            10000.0
# continent                           NaN
# Name: 33071, dtype: object
# name                   Hairo Timaná
# position                Centre-Back
# age                            22.0
# origin_club            Without Club
# country_origin_club             NaN
# new_club               Colón C-3 FC
# country_new_club             Panama
# cost                        75000.0
# continent                       NaN
# Name: 33100, dtype: object
# name                    Razvan Pavalache
# position                      Right-Back
# age                                 20.0
# origin_club                 Without Club
# country_origin_club                  NaN
# new_club               CS Viitorul Ianca
# country_new_club                 Romania
# cost                             10000.0
# continent                            NaN
# Name: 33117, dtype: object
# name                     Pedro Chic
# position                   midfield
# age                             NaN
# origin_club            Without Club
# country_origin_club             NaN
# new_club                  Quiché FC
# country_new_club          Guatemala
# cost                        10000.0
# continent                       NaN
# Name: 33274, dtype: object
# name                      Fitrah Ramadhan
# position               Defensive Midfield
# age                                  23.0
# origin_club                  Without Club
# country_origin_club                   NaN
# new_club                     PSCS Cilacap
# country_new_club                Indonesia
# cost                              10000.0
# continent                             NaN
# Name: 33395, dtype: object
# name                        Anrie Chase
# position                    Centre-Back
# age                                18.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club               VfB Stuttgart II
# country_new_club                Germany
# cost                           300000.0
# continent                           NaN
# Name: 33459, dtype: object
# name                      Nazih Ilihoum
# position               Central Midfield
# age                                22.0
# origin_club                Without Club
# country_origin_club                 NaN
# new_club                      ORB Akbou
# country_new_club                Algeria
# cost                            75000.0
# continent                           NaN
# Name: 33468, dtype: object
# name                           Marco Contescu
# position                       Centre-Forward
# age                                      19.0
# origin_club                      Without Club
# country_origin_club                       NaN
# new_club               Unirea Sannicolau Mare
# country_new_club                      Romania
# cost                                  10000.0
# continent                                 NaN
# Name: 33498, dtype: object

# %%
clubs
# Out:
# ['NK Vinodol',
#  'Finn Harps',
#  'Disqualification',
#  'Esteghlal Mollasani',
#  'Mes Shahr Babak FC',
#  'Deportivo Alavés B',
#  'Khimik Dzerzhinsk']

# %%
ffx = webdriver.Chrome()
li6 = []
ffx.get("https://www.transfermarkt.com")
for i in clubs:
    ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').send_keys(i) # Search with player name
    ffx.find_element(By.CSS_SELECTOR,'[class="tm-header__input--search-send"]').send_keys(Keys.ENTER) # press Enter Key
    try:
        x = ffx.find_element(By.CSS_SELECTOR,'img[class= "flaggenrahmen"]').get_attribute('alt')
        li6.append(x)
    except :
        li6.append('unknown')
    ffx.find_element(By.CSS_SELECTOR, '[class="tm-header__input--search-field"]').clear()
ffx.quit()
print(li6)
# Out:
# ['Croatia', 'Ireland', 'unknown', 'Iran', 'Iran', 'Spain', 'Russia']

# %%
dic = dict(zip(index,li6))

# %%
data.fillna({'country_origin_club': dic},inplace=True)

# %% [markdown]
# ## data visulizatoin

# %%
data.age.min()
# Out:
# 15.0

# %%
data.age.max()
# Out:
# 46.0

# %%
plt.style.use('ggplot')
# %matplotlib inline

L15_20 = len(data[(data.age >= 15) & (data.age <= 20) ])
L21_25 = len(data[(data.age >= 21) & (data.age <= 25) ])
L26_30 = len(data[(data.age >= 26) & (data.age <= 30) ])
L31_35 = len(data[(data.age >= 31) & (data.age <= 35) ])
L36_40 = len(data[(data.age >= 36) & (data.age <= 40) ])
L41_46 = len(data[(data.age >= 41) & (data.age <= 46) ])

ageRanges = [L15_20, L21_25, L26_30, L31_35, L36_40, L41_46]
label = ['under 20', '21-25', '26-30', '31-35', '36-40', 'above 40']
#explode = (.4,.2,0,0,.4)

plt.title('distribuation of Players Age')

plt.pie(ageRanges, labels=label, pctdistance=0.8,autopct='%.2f %%', radius=2)
plt.tight_layout()
plt.show()

# %%
plt.bar(label,ageRanges)
# Out:
# <BarContainer object of 6 artists>

# %%
sns.displot(data.age, kde= True)

# %%
x = data.cost/1000
sns.displot(x,kind='kde')

# %%
data.isna().sum()         # na values
# Out:
# name                      5
# position                  0
# age                     126
# origin_club               0
# country_origin_club     928
# new_club                  4
# country_new_club       5574
# cost                      4
# continent               935
# dtype: int64

# %%
data.drop(['country_origin_club','country_new_club'], axis=1, inplace=True)

# %% [markdown]
# #

# %% [markdown]
# #

# %% [markdown]
# # Modelling

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.age, data.cost, test_size=0.33, random_state=42)

# %%
model = linear_model.LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_772/2721349307.py in <module>
# ----> 1 model.fit(X_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869         raise ValueError("y cannot be None")
#     870
# --> 871     X = check_array(X, accept_sparse=accept_sparse,
#     872                     accept_large_sparse=accept_large_sparse,
#     873                     dtype=dtype, order=order, copy=copy,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     692             # If input is 1D raise error
#     693             if array.ndim == 1:
# --> 694                 raise ValueError(
#     695                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     696                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[28. 27. 21. ... 29. 21. 24.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
